# %%
from omrdatasettools import Downloader, OmrDataset
import os
from obb_anns import OBBAnns
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_48592/1403079252.py in <module>
#       3 from obb_anns import OBBAnns
#       4 from PIL import Image
# ----> 5 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !cp -R /userfiles/cakarsubasi18/DeepScores/ds2_dense /scratch/users/cakarsubasi18/JupyterWorkspace/DeepScores

# %%
o = OBBAnns('DeepScores/deepscores_train.json')
o.load_annotations()

# %%
img_idxs = [i for i in range(50)]

# %%
#imgs, anns = o.get_img_ann_pair(img_idxs)
if not os.path.exists('temp'):
    os.mkdir('temp')
o.visualize(1, out_dir='temp', show=False)
# Out:
# Visualizing DeepScores/images/lg-139957803-aug-emmentaler--page-5.png...

# %%
imgs = os.walk('temp')

for idx in imgs:
    print(idx)
# Out:
# ('temp', [], ['04-14_163933.png'])

# %%
o.get_img_ann_pair(idxs=[0])
# Out:
# ([{'id': 2,
#    'filename': 'lg-94161796-aug-gonville--page-3.png',
#    'width': 1960,
#    'height': 2772,
#    'ann_ids': ['1113019',
#     '1113020',
#     '1113021',
#     '1113022',
#     '1113023',
#     '1113024',
#     '1113025',
#     '1113026',
#     '1113027',
#     '1113028',
#     '1113029',
#     '1113030',
#     '1113031',
#     '1113032',
#     '1113033',
#     '1113034',
#     '1113035',
#     '1113036',
#     '1113037',
#     '1113038',
#     '1113039',
#     '1113040',
#     '1113041',
#     '1113042',
#     '1113043',
#     '1113044',
#     '1113045',
#     '1113046',
#     '1113047',
#     '1113048',
#     '1113049',
#     '1113050',
#     '1113051',
#     '1113052',
#     '1113053',
#     '1113054',
#     '1113055',
#     '1113056',
#     '1113057',
#     '1113058',
#     '1113059',
#     '1113060',
#     '1113061',
#     '1113062',
#     '1113063',
#     '1113064',
#     '1113065',
#     '1113066',
#     '1113067',
#     '1113068',
#     '1113069',
# ...

# %%
Image.open('temp/04-14_163933.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1960x2772 at 0x2B4535E87750>

# %%
# Faster copy
#!mkdir /scratch/users/cakarsubasi18/DeepScores
#!cp /userfiles/cakarsubasi18/DeepScores/zips/ds2_dense.tar.gz /scratch/users/cakarsubasi18/DeepScores
#!tar -xf /scratch/users/cakarsubasi18/DeepScores/ds2_dense.tar.gz
